# %% [markdown]
# # Predicting Company Bankruptcy using Liability Financial Metrics

# %% [markdown]
# # Introduction
#
# **Background Information**
#
# The occurrence of bankruptcies that are linked to business failures is becoming a common concern for many companies and their stakeholders. They can occur through the natural course of progression (such as smartphone cameras replacing the non-professional dedicated camera market), or be exacerbated through exogenous shocks (such as the dot-com bubble of 2001, or the 2007 financial crisis).
#
# **Predictive Question**
#
# In this analysis, we will determine **if we can predict the looming bankruptcy of a company based on a variety of fundamental financial metrics, specifically related to debt and liabilities**. Moreover, we will be looking at metrics that may indicate an imminent bankruptcy as opposed to a drawn-out downfall.
#
# **Dataset**
#
# We will use the Taiwanese Bankruptcy Prediction dataset from the Taiwan Economic Journal (TEJ), spanning from 1999-2009. Since its 1990 inception, the TEJ has focused on delivering essential financial market data. Within this 1999-2009 period, the TEJ recorded 220 observations of bankruptcy within the total 6,819 observations they collected data on (“About TEJ - TEJ,” 2023). Company bankruptcy was defined based on the business rules of the Taiwan Stock Exchange (Lyon, 2017).  The dataset comes from the UCI Machine Learning Repository.
#
# The dataset includes 95 columns of financial metrics, and a 96th column for a bankruptcy flag (yes/no).
# We will use the **bankruptcy flag as our classification variable**.

# %% [markdown]
# ### Table of Figures

# %% [markdown]
# #### Tables
# - Table 1: Preliminary overview of tidied data
# - Table 2: Overview of statistical properties of data columns
# - Table 3: Overview, after removing duplicated or reciprocal columns
# - Table 4: Finalized dataset following tidying, wrangling, and integrity checks
# - Table 5: Summary of classification, counts in both the training and testing sets
# - Table 6: Preliminary analysis of data set
# - Table 7: Upsampled, scaled, and centered training set
# - Table 8: Accuracy, recall, kappa, and precision of the predictive model
#
# #### Figures
# - Figure 1: Density plot of preliminary analysis, examining current liabilities over liability, debt ratio, and quick assets over current liabilities
# - Figure 2: Comparing the accuracy estimate, versus the K nearest neighbours
# - Figure 3: Confusion matrix, comparing truth versus prediction
# - Figure 4: Comparing the accuracy, recall, kappa, and precision of the predictive model

# %% [markdown]
# # Methods & Results

# %% [markdown]
# The process will start by reading necessary libraries:

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(janitor)

install.packages("psych") #this is loaded to obtain a basic description of the data set
library(psych) 
install.packages("themis") #this is loaded to for the step_upsample funciton used in the recipe
library(themis)

options(repr.matrix.max.rows = 6)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.2”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.5     ✔ rsample      1.2.0
# ✔ dials        1.2.0     ✔ tune         1.1.2
# ✔ infer        1.0.5     ✔ workflows    1.1.3
# ✔ modeldata    1.2.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.1.1     ✔ yardstick    1.2.0
# ✔ recipes      1.0.8
#
# ...

# %% [markdown]
# To read the data, we will do the following:
# 1) Download the zip file from the UCI Machine Learning Repository
# 2) Specify where to save the zip file
# 3) Unzip the file to our desired location

# %%
# Set an initial seed so analysis does not change between instances of reloading the file
set.seed(7834) 

#get file, which is stored as a .zip
url <- "https://archive.ics.uci.edu/static/public/572/taiwanese+bankruptcy+prediction.zip"
data_directory <- "data/"

dir.create(file.path(dirname(data_directory), "data")) #create the directory to save the file

zip_file_name <- "data.zip"
download.file(url, paste(data_directory, zip_file_name, sep = ""), mode = "wb") #download file
#unzip the zipfile
unzip(paste(data_directory, zip_file_name, sep=""),exdir=data_directory) #unzip the data
# Out:
# Warning message in dir.create(file.path(dirname(data_directory), "data")):
# “'./data' already exists”

# %%
taiwan_data <- read_csv("data/data.csv") |>
               clean_names(replace = c('/' = " over ", '%' = "percent")) #the headers have numerous spaces and/or invalid characters.  But we want to preserve % as "percent", and / as "over".
# Out:
# Rows: 6819 Columns: 96
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (96): Bankrupt?, ROA(C) before interest and depreciation before interest...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# The data set is quite clean:
# - The prediction column, bankruptcy, contains either a 0 (if the company is not bankrupt) or 1 (if the company is bankrupt).
# - No  invalid data (ie., factors in a double column)
# - No  missing data (ie., no blank or NA)
#
# However, it is also highly imbalanced. From the 6,819 observations, only 220 are labeled bankrupt, which represents approximately 3.23% of the observations.
#
# In the process of tidying, we made the following adjustments:
#  1) Clean the headers of the data as numerous of them have spaces and/or invalid characters (such as "?" or "/")
#  2) Change the classification column, "bankrupt", to a factor and rename the 1 and 0 by their respective human definitions (1 = Bankrupt, 0 = Not Bankrupt).  **This is what we are going to be predicting.**
#  3) Select the columns necessary for the analysis.  As we are determining the bankruptcy of a company based on a subset of debt and liability metrics, we will initially filter the data for columns containing the word "debt", and columns containing any form of the word "liability."
#  4) Remove preliminary columns that fall within the selection but do not have relevant data for us, like the "interest_bearing_debt_interest_rate" and "liability_assets_flag" columns (since the interest rate is not a financial metric, hence beyond the scope of our analysis, and the liability asset flag is a 0 or 1, classification variable).
#  5) Mutated the "debt_ratio_percent" column with the multiplication of 100 to provide a more human-understandable value for the category in a percentage form.

# %%
taiwan_preliminary <- taiwan_data |>
                mutate(bankrupt = fct_recode(factor(bankrupt), "Bankrupt" = '1', "Not Bankrupt" = '0'), debt_ratio_percent = debt_ratio_percent * 100) |> #change numerical values to factors/classifications.
                select(bankrupt, contains("debt"), contains("liabilit")) |>  #select 1) classification column (bankrupt), 2) columns containing "Debt", and 3) columns containing any form of liability
                select(!c(interest_bearing_debt_interest_rate, liability_assets_flag)) #remove two additional columns - interest rate, and liability asset flag.

taiwan_preliminary
# Out:
#      bankrupt     total_debt_over_total_net_worth debt_ratio_percent
# 1    Bankrupt     0.02126592                      20.75763
# 2    Bankrupt     0.01250239                      17.11763
# 3    Bankrupt     0.02124769                      20.75158
# ⋮    ⋮            ⋮                               ⋮
# 6817 Not Bankrupt 0.0013915866                    3.893944
# 6818 Not Bankrupt 0.0038163762                    8.697887
# 6819 Not Bankrupt 0.0004614304                    1.414880
#      contingent_liabilities_over_net_worth quick_assets_over_current_liability
# 1    0.006478502                           0.001996771
# 2    0.005835039                           0.004136030
# 3    0.006561982                           0.006302481
# ⋮    ⋮                                     ⋮
# 6817 0.005365848                           0.035531293
# 6818 0.007067734                           0.007753306
# 6819 0.006368212                           0.051480515
# ...

# %% [markdown]
# _Table 1: Preliminary overview of tidied data_

# %%
# High-level overview of our preliminary data
describe(taiwan_preliminary, IQR = 0)
# Out:
#                                     vars n    mean         sd
# bankrupt*                           1    6819 1.032263e+00 1.767102e-01
# total_debt_over_total_net_worth     2    6819 4.416337e+06 1.684069e+08
# debt_ratio_percent                  3    6819 1.131771e+01 5.392031e+00
# ⋮                                   ⋮    ⋮    ⋮            ⋮
# current_liability_to_current_assets 17   6819 0.03150637   0.03084469
# liability_to_equity                 18   6819 0.28036515   0.01446322
# equity_to_liability                 19   6819 0.04757836   0.05001372
#                                     median       trimmed      mad         min
# bankrupt*                            1.000000000  1.000000000 0.000000000 1
# total_debt_over_total_net_worth      0.005546284  0.006182498 0.004342654 0
# debt_ratio_percent                  11.140671766 11.142242947 5.638693957 0
# ⋮                                   ⋮            ⋮            ⋮           ⋮
# ...

# %% [markdown]
# _Table 2: Overview of statistical properties of data columns_

# %% [markdown]
# The initial tiding and wrangling narrowed down the financial metrics to those that include debt and/or liabilities to 19 columns. Within that 19, we have the following:
#
# - **Bankruptcy Flag (Y/N)**
# - Total debt over total net worth
# - **Debt ratio (as a percentage)**
# - Contingent liabilities over net worth
# - **Quick assets over current liability**
# - Cash over current liability
# - Current liability to assets
# - Operating funds to liability
# - Inventory over current liability
# - **Current liabilities over liability**
# - ~~Current liabilities over equity~~
# - Long-term liability to current assets
# - ~~Current liability to liability~~
# - Current liability to equity
# - Equity to long-term liability
# - Cash flow to liability
# - Current Liability to current assets
# - Liability to Equity
# - ~~Equity to liability~~
#
# That said, we noticed something strange when doing data wrangling. Some of the categories had identical values but with similar, unique names. For instance: "current_liabilities_over_liability" shared identical data with "current_liability_to_liability".  We ultimately determined the categories were oriented in such a way so that other data scientists, who may be looking specifically for "current liabilities" vs "current liability" can use those columns.
#
# To preserve the quality and integrity of our analysis, we will not be using duplicated or reciprocal categories. They are represented by the strikethrough in the list above.

# %%
# Removing the three specified variables to preserver integrity
taiwan_integrity <- taiwan_preliminary |>
               select(-current_liability_to_liability, -current_liabilities_over_equity, -equity_to_liability) 
taiwan_integrity
# Out:
#      bankrupt     total_debt_over_total_net_worth debt_ratio_percent
# 1    Bankrupt     0.02126592                      20.75763
# 2    Bankrupt     0.01250239                      17.11763
# 3    Bankrupt     0.02124769                      20.75158
# ⋮    ⋮            ⋮                               ⋮
# 6817 Not Bankrupt 0.0013915866                    3.893944
# 6818 Not Bankrupt 0.0038163762                    8.697887
# 6819 Not Bankrupt 0.0004614304                    1.414880
#      contingent_liabilities_over_net_worth quick_assets_over_current_liability
# 1    0.006478502                           0.001996771
# 2    0.005835039                           0.004136030
# 3    0.006561982                           0.006302481
# ⋮    ⋮                                     ⋮
# 6817 0.005365848                           0.035531293
# 6818 0.007067734                           0.007753306
# 6819 0.006368212                           0.051480515
# ...

# %% [markdown]
# _Table 3: Overview after removing duplicated or reciprocal columns_

# %% [markdown]
# In spot-checking the data, we noticed three observations that did not make sense as they had quick ratios exceeding 1,000,000,000.  Typically, a quick ratio should remain around 1 or slightly below. However, falling below 1 can happen under certain circumstances, such as if the company has favourable terms with its lenders or is utilizing debt financing (Girardin, 2022).
#
# We filtered out the observations where "quick_assets_over_current_liability" exceeded 1.0 as they could significantly skew the data. This leaves us with 6,816 observations.

# %%
# Spot check quick_assets_over_quick_Liability and make integrity adjustments
head(arrange(taiwan_integrity, -quick_assets_over_current_liability), n = 6)

taiwan_tidy <- taiwan_integrity |>
                filter(quick_assets_over_current_liability <= 1)
# Out:
#   bankrupt     total_debt_over_total_net_worth debt_ratio_percent
# 1 Not Bankrupt 1.877183e-02                    19.9534420
# 2 Not Bankrupt 8.266535e-03                    14.0550836
# 3 Not Bankrupt 1.945349e-01                    31.2755087
# 4 Not Bankrupt 4.740000e+08                     0.1511624
# 5 Not Bankrupt 0.000000e+00                     0.0000000
# 6 Not Bankrupt 2.237846e-03                     5.7985912
#   contingent_liabilities_over_net_worth quick_assets_over_current_liability
# 1 0.005505387                           8.820000e+09
# 2 0.005378035                           8.140000e+09
# 3 0.005365848                           7.540000e+09
# 4 0.006179317                           1.000000e+00
# 5 0.005365848                           3.251893e-01
# 6 0.005365848                           2.750005e-01
#   cash_over_current_liability current_liability_to_assets
# 1 0.0001692919                0.207914962
# 2 0.0005556540                0.147365330
# ...

# %% [markdown]
# _Table 4: Finalized dataset following tidying, wrangling, and integrity checks_

# %% [markdown]
# Following the data wrangling and tidying, we separated the data into respective training and testing groups.  We used a proportion of 75% for separating the data by using the prediction column, and bankrupt as the strata.  The proportion of 75% was given the relatively small sample size of our classification variable (75%), as we wanted to provide sufficient data for training, but also have enough for testing purposes.

# %%
# We will separate our data into respective training and testing groups.
taiwan_initial_split <- initial_split(taiwan_tidy, prop = 0.75, strata = bankrupt)
taiwan_initial_training <- training(taiwan_initial_split)
taiwan_initial_testing <- testing(taiwan_initial_split)

# %% [markdown]
# A summary of the split is below.

# %%
# Set an initial seed so analysis does not change between instances of reloading the file
set.seed(7834) 
taiwan_training_count <- taiwan_initial_training |>
                                          group_by(bankrupt) |>
                                          summarize(observations_training = n())
taiwan_testing_count <- taiwan_initial_testing |>
                                          group_by(bankrupt) |>
                                          summarize(observations_testing = n())
taiwan_training_count
taiwan_testing_count
# Out:
#   bankrupt     observations_training
# 1 Not Bankrupt 4947
# 2 Bankrupt      165
#   bankrupt     observations_testing
# 1 Not Bankrupt 1649
# 2 Bankrupt       55

# %% [markdown]
# _Table 5: Summary of classification counts in both the training and testing sets_

# %% [markdown]
# ### Preliminary Analysis

# %% [markdown]
# We will use four key variables for our preliminary analysis to provide an idea of the validity of our thesis:
# - **Bankruptcy Flag:** our predictor variable.
# - **Debt ratio (as a percentage):** represents the amount of leverage used by a company in terms of total debt to total assets (Hayes, 2023).
# - **Quick assets over current liability:** also known as the "quick ratio", represents the extent to which a business can pay its short-term obligations with its most liquid assets, not including inventory (Beaver, 2022).
# - **Current liabilities over liability:** represents the proportion of all liabilities that are due within the next 12 months to the total amount of liabilities (“What Are Current Liabilities,” n.d.).
#
# The _quick ratio_ will give us an idea of the company's ability to settle short-term obligations, while _current liabilities over liability_ will provide an outline of which portion of the company's total obligations will become due within the next 12 months.  Finally, the _debt ratio_ outlines how much of the company is made up of debt.

# %%
taiwan_preliminary <- taiwan_initial_training |>
                select(bankrupt, debt_ratio_percent, quick_assets_over_current_liability, current_liabilities_over_liability)
taiwan_preliminary
# Out:
#      bankrupt     debt_ratio_percent quick_assets_over_current_liability
# 1    Bankrupt     20.75763           0.001996771
# 2    Bankrupt     17.11763           0.004136030
# 3    Bankrupt     20.75158           0.006302481
# ⋮    ⋮            ⋮                  ⋮
# 5110 Not Bankrupt 3.893944           0.035531293
# 5111 Not Bankrupt 8.697887           0.007753306
# 5112 Not Bankrupt 1.414880           0.051480515
#      current_liabilities_over_liability
# 1    0.6762692
# 2    0.3085886
# 3    0.4460275
# ⋮    ⋮
# 5110 0.5539642
# 5111 0.8932409
# 5112 1.0000000

# %% [markdown]
# _Table 6: Preliminary analysis data set_

# %% [markdown]
# Three new data frames are added to aid in the visualization and summarization of our data, using the four key variables from taiwan_preliminary as the basis.

# %%
# This creates a new dataframe for the purposes of organizing the columns to better fit our intended visualizations.
taiwan_viz <- taiwan_preliminary |>
              pivot_longer(cols = -bankrupt, names_to = 'category', values_to ='value') 

# This creates a new dataframe to group the data by bankrupt and a respective mean value for each column.
taiwan_preliminary_all_mean_summary <- taiwan_preliminary |>
                                          group_by(bankrupt) |>
                                          summarize_all(mean)

# This creates a new dataframe for the purposes of highlighting the mean value of the taiwan_viz dataframe and to add labels to the graph.
taiwan_viz_mean <- taiwan_preliminary_all_mean_summary |>
              pivot_longer(cols = -bankrupt, names_to = 'category', values_to ='value_mean') |>
              mutate(x = c(6, 0.03, 0.45, 39, 0.0025, 0.45), y = c(3, 1, 4.5, 3.5, 1.3, 4))

# %% [markdown]
# Commentary on summarizing the data set which is relevant for exploratory data analysis and related to the planned analysis.
#
#
# We opted to use a density plot to visualize the distribution of our numeric variables. It allows us to contrast the ranges of differences between bankrupt and not-bankrupt companies.
#
# Given our variables resolve to ratios, we determined scaling the x-axis logarithmically, which provided the most clear depiction of ranges.  Finally, we highlighted the average for each variable based on bankruptcy status.

# %%
options(repr.plot.height = 8, repr.plot.width = 10)

taiwan_plot_2 <- taiwan_viz |> 
                    ggplot(aes(value, fill = bankrupt)) +
                    geom_density(alpha = 0.4, colour = 'white') +
                    facet_wrap(vars(category), nrow = 3, scales = 'free') +
                    theme_minimal() +
                    scale_x_log10() + #we scale the X axis, as all categories observe a large range in their values
                    geom_vline(data = taiwan_viz_mean, aes (xintercept=value_mean, color=bankrupt), linetype="dashed") +
                    geom_text(data = taiwan_viz_mean, aes(label = paste("Mean: ", round(value_mean,4)), x = x, y = y,  colour = bankrupt)) +
                    labs(x = "Value", y = "Density", title = "Density Plot Visualizing Three Key Financial Metrics", colour = "Legend", fill = "Legend") +
                    theme(text = element_text(size = 10))

taiwan_plot_2
# Out:
# Warning message in scale_x_log10():
# “log-10 transformation introduced infinite values.”
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# _Figure 1: Density plot of preliminary analysis, examining current liabilities over liability, debt ratio, and quick assets over current liabilities_

# %% [markdown]
# The visualization strongly agrees with the thesis. It showed that bankrupt companies are more likely to have a higher amount of debt and that non-bankrupt companies generally have a higher level of quick assets to cover short-term obligations and expenses.
#
# Interestingly, the ratio of current liabilities over liability did not differ between the two by an appreciable amount.

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Our analysis will use a knn classification for predicting. We opted to use this model as our predictor variable is a binary bankrupt or not-bankrupt.
#
# As a result of the significant imbalance between bankrupt vs not bankrupt observations, we incorporated the (step_upsample) function to replicate rows of our data set to make the occurrence of observations equal for both bankrupt and not bankrupt.  Then, we scaled and centered the data to remove any weighting bias of any factor.

# %%
taiwan_recipe <- recipe(bankrupt ~ . , data = taiwan_initial_training) |>
                step_upsample(bankrupt) |> #replicates rows in the dataset to make the observations for both bankrupt and not bankrupt equal.
                step_scale(all_predictors()) |>
                step_center(all_predictors()) 

taiwan_scaled <- taiwan_recipe |>  
                     prep() |> 
                     bake(taiwan_initial_training)

taiwan_scaled
# Out:
#      total_debt_over_total_net_worth debt_ratio_percent
# 1    -0.05721859                     0.8310596
# 2    -0.05721859                     0.2943146
# 3    -0.05721859                     0.8301680
# ⋮    ⋮                               ⋮
# 5110 -0.05721859                     -1.6556211
# 5111 -0.05721859                     -0.9472425
# 5112 -0.05721859                     -2.0211783
#      contingent_liabilities_over_net_worth quick_assets_over_current_liability
# 1    -0.03887893                           -0.4035097
# 2    -0.05202174                           -0.2709650
# 3    -0.03717384                           -0.1367354
# ⋮    ⋮                                     ⋮
# 5110 -0.06160503                            1.67423056
# 5111 -0.02684379                           -0.04684488
# 5112 -0.04113162                            2.66241640
#      cash_over_current_liability current_liability_to_assets
# 1    -0.1452712                   0.4534711
# ...

# %% [markdown]
# _Table 7: Upsampled, scaled, and centred training set_

# %% [markdown]
# ### Fine Tuning

# %% [markdown]
# To train and test the model, we used VFold as the cross-validator.

# %%
# Set an initial seed so analysis does not change between instances of reloading the file
set.seed(7834) 

# Specify the vfold with v folds, using our classifier bankrupt as the strata
taiwan_vfold <- vfold_cv(taiwan_initial_training, v = 5, strata = bankrupt)

# Specify tune() for the neighbours to determine the most accurate value
knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
       set_engine("kknn") |>
       set_mode("classification")

knn_results <- workflow() |>
       add_recipe(taiwan_recipe) |>
       add_model(knn_tune) |>
       tune_grid(resamples = taiwan_vfold, grid = 10) |>
       collect_metrics()

# %%
options(repr.plot.height = 2, repr.plot.width = 6)

accuracies <- knn_results |> 
       filter(.metric == "accuracy")

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean))+
       geom_point() +
       geom_line() +
       labs(x = "Neighbors (K nearest)", y = "Accuracy Estimate", title="Accuracy Estimate versus K nearest neighbours") +
       theme(plot.title = element_text(hjust = 0.5)) +
       scale_x_continuous(breaks = seq(1, 15, by = 1)) +  # adjusting the x-axis
       scale_y_continuous(limits = c(0.85, 0.95)) # adjusting the y-axis
accuracy_versus_k
# Out:
# plot without title

# %% [markdown]
# _Figure 2: Comparing the accuracy estimate, versus the K nearest neighbours_

# %% [markdown]
# ### Predicting the Data

# %% [markdown]
# Following the fine tuning, we chose K=3 neighbours as we wanted to remove any ties which could be brought about with the even number K=2.
#
# Next, we will create the knn specification to fit the pre-processed training data.

# %%
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) |>
       set_engine("kknn") |>
       set_mode("classification")

taiwan_fit <- workflow() |>
       add_recipe(taiwan_recipe) |>
       add_model(knn_spec) |>
       fit(data = taiwan_initial_training)

# %% [markdown]
# After our model is trained, we use the testing data to predict the bankruptcy status.

# %%
taiwan_test_predictions <- predict (taiwan_fit, taiwan_initial_testing) |>
                            bind_cols(taiwan_initial_testing)

taiwan_conf_mat <- taiwan_test_predictions |>
                  conf_mat(truth = bankrupt, estimate = .pred_class)

taiwan_conf_mat
# Out:
#               Truth
# Prediction     Not Bankrupt Bankrupt
#   Not Bankrupt         1569       37
#   Bankrupt               80       18

# %% [markdown]
# _Figure 3: Confusion matrix, comparing truth versus prediction_

# %%
options(repr.plot.height = 6, repr.plot.width = 6)

# Check order of positive class
taiwan_test_predictions |> pull(bankrupt) |> levels()

# Analyze the accuracy, recall, and precision of the model, including its kappa to measure inter-rater reliability.
taiwan_prediction_accuracy <- taiwan_test_predictions |>
                             metrics(truth = bankrupt, estimate = .pred_class)
taiwan_prediction_recall <- taiwan_test_predictions |>
                             recall(truth = bankrupt, estimate = .pred_class, event_level = "second") # Set "Bankrupt" as the positive class
taiwan_prediction_precision <- taiwan_test_predictions |>
                             precision(truth = bankrupt, estimate = .pred_class, event_level = "second") # Set "Bankrupt" as the positive class

taiwan_prediction_metrics <- taiwan_prediction_accuracy |>
                             bind_rows(taiwan_prediction_recall) |>
                             bind_rows(taiwan_prediction_precision) |>
                             arrange(-.estimate)

# Create a plot of the analysis
taiwan_prediction_metrics_plot <- taiwan_prediction_metrics |>
                                  ggplot(aes(x=reorder(.metric, -.estimate), y=.estimate)) +
                                  geom_bar(stat = "identity", aes(fill=.metric)) +
                                  scale_y_continuous(labels = scales::percent_format(), limits = c(0,1)) +
                                  labs(x="Metric", y="Value [0, 100%]", title="Comparison of Accuracy, Recall, Kappa, and Precision") +
                                  theme(plot.title = element_text(hjust = 0.5), legend.position = "none")
taiwan_prediction_metrics
# Out:
# [1] "Not Bankrupt" "Bankrupt"
#   .metric   .estimator .estimate
# 1 accuracy  binary     0.9313380
# 2 recall    binary     0.3272727
# 3 kap       binary     0.2023110
# 4 precision binary     0.1836735

# %% [markdown]
# _Table 8: Accuracy, recall, kappa, and precision of predictive model_

# %%
taiwan_prediction_metrics_plot
# Out:
# plot without title

# %% [markdown]
# _Figure 4: Comparing the accuracy, recall, kappa, and precision of the predictive model_

# %% [markdown]
# # Discussion

# %% [markdown]
# Our model has the following characteristics:
# - Accuracy: 93.1%
# - Recall: 32.7%
# - Kappa: 20.2%
# - Precision: 18.4%
#
# Overall, the accuracy of the model had a strong capability to correctly predict the bankruptcy status of a particular testing observation, relative to all testing observations. However, the model's recall shows that it's not very good at finding "Bankrupt" observations in the testing data. Lastly, the precision characteristic was the weakest in its ability to predict the correct "Bankrupt" predictions, relative to all "Bankrupt" predictions in the testing set.
#
# Furthermore, diving in deeper we see that the Kappa is only at 20.2%. The inter-rater reliability is exceptionally low.  It's suggested that "the Kappa result be interpreted as follows: values ≤ 0 as indicating no agreement and 0.01–0.20 as none to slight, 0.21–0.40 as fair, 0.41– 0.60 as moderate, 0.61–0.80 as substantial, and 0.81–1.00 as an almost perfect agreement" (McHugh, 2012). Hence, our Kappa then indicates there is essentially zero agreement, and that the model does not perform a satisfactory job in predicting if a company will become bankrupt.
#
# Plotting the confusion matrix, it explains why our Kappa is low:

# %%
options(repr.plot.height = 8, repr.plot.width = 8)

# Recreate the confusion matrix in a form we can mapipulate for a ggplot graphic
predictor <- c("Not Bankrupt", "Bankrupt")
not_bankrupt <- c(sum(taiwan_test_predictions$.pred_class == "Not Bankrupt" & taiwan_test_predictions$bankrupt == "Not Bankrupt"), sum(taiwan_test_predictions$.pred_class == "Bankrupt" & taiwan_test_predictions$bankrupt == "Not Bankrupt"))
bankrupt <- c(sum(taiwan_test_predictions$.pred_class == "Not Bankrupt" & taiwan_test_predictions$bankrupt == "Bankrupt"), sum(taiwan_test_predictions$.pred_class == "Bankrupt" & taiwan_test_predictions$bankrupt == "Bankrupt"))

# Configure the dataframe in a way to be utilized by ggplot
conf <- data.frame(predictor, not_bankrupt, bankrupt) |>
        pivot_longer(c(not_bankrupt, bankrupt), names_to = "actual", values_to = "values") |>
        mutate(actual = fct_recode(actual, "Bankrupt" = 'bankrupt', "Not Bankrupt" = 'not_bankrupt')) #change numerical values to factors/classifications.



# Plot the confusion matrix, showing which % was correctly predicted
conf_bar_plot <- conf |>
                    ggplot(aes(x=actual, y = values, fill = predictor)) +
                    geom_bar(stat = "identity", position = "fill") +
                    scale_y_continuous(labels = scales::percent_format()) +
                    labs(x = "Actual bankruptcy status", fill = "Predicted bankruptcy status", y = "Proportion of total observations", title = "Proportion of Bankrupt and Not Bankrupt \n predicted correctly") +
                    geom_text(aes(label = values), colour = "white", position = position_fill(vjust = 0.5)) +
                    theme(plot.title = element_text(hjust = 0.5))
conf_bar_plot
# Out:
# plot without title

# %% [markdown]
# _Figure 4: Confusion matrix, comparing proportion of total observations against predicted and actual bankruptcy status_

# %% [markdown]
# Although the model correctly predicted "Not Bankrupt" 1,569 out of 1,649 times (95.1%), it only correctly predicted "Bankrupt" 18 out of 55 times (32.7%), resulting in a low kappa. Given the promising preliminary analysis and accuracy, the precision, recall, and kappa were not what we were expecting.
#
# However, upon reflection, we think this makes sense for a number of reasons:
# 1) **Between the years of collection (1999-2009) there were two exogenous shocks:** the 2001 dot-com bubble, and the 2007 financial crisis.  Given the data lacks an indicator of year, it is not known how either of those shocks affected the data (if at all).  It is possible the sudden onset of those shocks caused the firms to fail before they published their next-quarter results, which then would not be captured in the data.
# 2) **There is no indication of industry or sector.** A firm in the technology sector, for instance, may best be analyzed by its ability to cover liabilities (Traver, 2019), while a grocery store could best be analyzed by its ability to turn over inventory and increase profit margins (Tarver, n.d.). Given the lack of industry or sector, it is not known if there is an over/under-abundance of one particular area over another.
# 3) **The data is heavily skewed:** Only 220 of the 6,819 observations were Bankrupt.  Even with upsampling, there just is not enough variation in the source data to provide a compelling analysis. And, coupled with the previous two points, this issue is exacerbated.

# %% [markdown]
# Nevertheless, the findings from the analysis could have several impacts on companies. From the preliminary analysis, it is clear that there is a linkage between the amount of debt a company has (its debt ratio), and its ability to service ongoing liabilities (quick ratio).
#
# Although further refinement is likely required as outlined in the 3 points above, companies could use this insight to proactively manage their risks of bankruptcy, by identifying early bankruptcy warning signs and implementing strategies to address any financial instability. Likewise, Banks can use the findings to enhance their credit assessments, when lending out loans they can use the bankruptcy models to predict bankruptcy for their credit borrowers and reduce the likelihood of any defaults.

# %% [markdown]
# Future questions from this finding could include: how effective are traditional financial metrics in predicting bankruptcy relative to any other type or sources of data, or what is the quantifiable extent of the year and/or industry of each observation?

# %% [markdown]
# # References  (APA)

# %% [markdown]
#
# 1)  About TEJ - TEJ. (2023, May 6). Retrieved from TEJ website: https://www.tejwin.com/en/about/Lyon,
#
# 2) R. (2017, February 13).
#  UCI Machine Learning Repository. Retrieved from archive.ics.uci.edu website: https://archive.ics.uci.edu/dataset/372/htru2
#
# 3) Girardin, M. (2022, December 1). What Is the Quick Ratio? Definition and Formula. Retrieved from Forage website: https://www.theforage.com/blog/skills/quick-ratio
#
# 4) Beaver, S. (2022). When to Use Quick Ratio. Retrieved from Oracle NetSuite website: https://www.netsuite.com/portal/resource/articles/financial-management/quick-ratio.shtml
#
# 5) Hayes, A. (2023, July 7). Debt ratio. Retrieved from Investopedia website: https://www.investopedia.com/terms/d/debtratio.asp
#
# 6) McHugh, M. L. (2012). Interrater reliability: the Kappa Statistic. Biochemia Medica, 22(3), 276–282. Retrieved from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3900052/#:~:text=Cohen%20suggested%20the%20Kappa%20result,1.00%20as%20almost%20perfect%20agreement.
# 7) Tarver, E. (n.d.). What financial ratios are best to evaluate for consumer packaged goods? Retrieved from Investopedia website: https://www.investopedia.com/ask/answers/060515/what-are-some-important-financial-ratios-evaluate-respect-consumer-packaged-goods.asp
# 8) Traver, E. (2019). Key Financial Ratios to Analyze Tech Companies. Retrieved from Investopedia website: https://www.investopedia.com/articles/active-trading/082615/key-financial-ratios-analyze-tech-companies.asp
# 9) What are current liabilities. (n.d.). Retrieved from BDC.ca website: https://www.bdc.ca/en/articles-tools/entrepreneur-toolkit/templates-business-guides/glossary/current-liabilities
